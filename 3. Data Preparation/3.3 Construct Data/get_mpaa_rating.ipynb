# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\jilla\appdata\local\programs\python\python310\lib\site-packages (1.9.0)
# Requirement already satisfied: requests in c:\users\jilla\appdata\local\programs\python\python310\lib\site-packages (from tmdbv3api) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jilla\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jilla\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jilla\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jilla\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (2022.12.7)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tmdbv3api import TMDb
from tmdbv3api import Movie
from tmdbv3api.exceptions import TMDbException
import random
import pandas as pd
import csv
tmdb=TMDb()
tmdb.api_key='9cf68f4c97c8f0cc6bb9646da389a808'
tmdb.language='en'
movie=Movie()

# %%
full_data = pd.read_csv('merged_US_allscores_similarity.csv', header=0, index_col=0)

# %%
tmdb_ids = full_data['TMDB ID']

mpaa = {}
for id in tmdb_ids:
    try:
        int_id = int(id)
        movie_info=movie.details(int_id)
        if movie_info:
            release_dates=movie_info.get('release_dates',{})
            results=release_dates.get('results',[])

            for result in results:
            # THIS (BELOW) IS THE LINE ADDED FOR US RELEASE DATE ONLY
                if result.get('iso_3166_1')=='US':
                    for release_date in result.get('release_dates',[]):
                        if release_date.get('type')==3:
                    #Write the movie ID to the list
                            mpaa[int_id] = release_date.get('certification')
    except:
        pass

# %%
mpaa_df = pd.DataFrame({'TMDB ID': list(mpaa.keys()), 'MPAA_TMDB': list(mpaa.values())})
full_data_mpaa = full_data.merge(mpaa_df, 'left', left_on='TMDB ID', right_on='TMDB ID')
full_data_mpaa.to_csv('data_with_mpaa.csv')

# %%
full_data_mpaa
# Out:
#                                               Genres  \
# 0                                  Documentary Sport
# 1                Action Crime Drama Mystery Thriller
# 2                                              Drama
# 3                        Biography Drama History War
# 4     Action Adventure Comedy Horror Sci-Fi Thriller
# ...                                              ...
# 3590                             Action Comedy Crime
# 3591                     Biography Documentary Music
# 3592                                 Biography Drama
# 3593                                    Drama Family
# 3594                          Comedy Musical Romance
#
#                                              IMDB Title   MPAA  \
# 0                                  Into the Mind (2013)    NaN
# 1                                    Broken City (2013)      R
# 2                                Redwood Highway (2013)  PG-13
# 3                               Bless Me, Ultima (2012)  PG-13
# 4                                        Spiders (2013)  PG-13
# ...                                                 ...    ...
# 3590                               Dancing Ninja (2010)    NaN
# 3591  Ain't in It for My Health: A Film About Levon ...    NaN
# 3592                                      Leonie (2010)  PG-13
# 3593                        Ways to Live Forever (2010)  PG-13
# 3594                                 First Night (2010)    NaN
#
#           Domestic Distributor  Domestic Opening  \
# 0                          NaN               NaN
# 1        Twentieth Century Fox         8268908.0
# 2               Monterey Media              30.0
# 3         Arenas Entertainment          470109.0
# 4     Millennium Entertainment               NaN
# ...                        ...               ...
# 3590                       NaN               NaN
# 3591               Kino Lorber            7937.0
# 3592                       NaN               NaN
# 3593                       NaN               NaN
# 3594                       NaN               NaN
#
#                      Earliest Release Date  IMDB Budget  TMDB Budget  \
# 0                 January 31, 2014 (Spain)            0            0
# 1        January 18, 2013 (Domestic, EMEA)     35000000     56000000
# 2                April 11, 2014 (Domestic)            0            0
# 3             February 22, 2013 (Domestic)            0            0
# 4              February 8, 2013 (Domestic)            0      7000000
# ...                                    ...          ...          ...
# 3590  July 19, 2012 (United Arab Emirates)            0            0
# 3591             April 19, 2013 (Domestic)            0            0
# 3592             November 20, 2010 (Japan)            0            0
# 3593              October 29, 2010 (Spain)            0            0
# 3594     October 14, 2011 (United Kingdom)            0            0
#
#                 Genre ID                       Genre Name  ...  \
# 0                   [99]                  ['Documentary']  ...
# 1           [53, 80, 18]   ['Thriller', 'Crime', 'Drama']  ...
# 2                   [18]                        ['Drama']  ...
# 3            [18, 10752]                 ['Drama', 'War']  ...
# 4              [878, 53]  ['Science Fiction', 'Thriller']  ...
# ...                  ...                              ...  ...
# 3590        [28, 35, 80]    ['Action', 'Comedy', 'Crime']  ...
# 3591         [99, 10402]         ['Documentary', 'Music']  ...
# 3592                [18]                        ['Drama']  ...
# 3593         [18, 10751]              ['Drama', 'Family']  ...
# 3594  [35, 10402, 10749]   ['Comedy', 'Music', 'Romance']  ...
#
#      Simple Weight Star Score Log Weight Star Score  \
# 0                         0.0               0.00000
# 1                       470.0             459.47885
# 2                         0.0               0.00000
# 3                         0.0               0.00000
# 4                         0.0               0.00000
# ...                       ...                   ...
# 3590                      0.0               0.00000
# 3591                      0.0               0.00000
# 3592                      0.0               0.00000
# 3593                      0.0               0.00000
# 3594                      0.0               0.00000
#
#      Exponential Weight Star Score  \
# 0                         0.000000
# 1                       444.130435
# 2                         0.000000
# 3                         0.000000
# 4                         0.000000
# ...                            ...
# 3590                      0.000000
# 3591                      0.000000
# 3592                      0.000000
# 3593                      0.000000
# 3594                      0.000000
#
#      Movie Contribution to Director and Production Scores  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 3590                                                  0
# 3591                                                  0
# 3592                                                  0
# 3593                                                  0
# 3594                                                  0
#
#       Total Director Score  Avg Director Score Total Production Company Score  \
# 0                        0                 0.0                              0
# 1                       68                68.0                            557
# 2                        0                 0.0                              0
# 3                        0                 0.0                              0
# 4                        0                 0.0                            292
# ...                    ...                 ...                            ...
# 3590                     0                 0.0                              0
# 3591                     0                 0.0                              0
# 3592                     0                 0.0                             37
# 3593                     0                 0.0                              0
# 3594                     0                 0.0                              0
#
#       Avg Production Company Score Genre Cluster MPAA_TMDB
# 0                         0.000000             3
# 1                        61.888889             0         R
# 2                         0.000000             1     PG-13
# 3                         0.000000             2     PG-13
# 4                       146.000000             0     PG-13
# ...                            ...           ...       ...
# 3590                      0.000000             0        NR
# 3591                      0.000000             0        NR
# 3592                     18.500000             1     PG-13
# 3593                      0.000000             2     PG-13
# 3594                      0.000000             0
#
# [3595 rows x 40 columns]
