# %%
from tmdbv3api import TMDb
from tmdbv3api import Movie
from tmdbv3api.exceptions import TMDbException
import random
import pandas as pd
tmdb=TMDb()
tmdb.api_key='9cf68f4c97c8f0cc6bb9646da389a808'

# %%
movie=Movie()
tmdb.language='en'
movie = Movie()
movie_data = []
num_mov=0
target=100
while num_mov < target:
    try:
        random_movie_id = random.randint(1,10000)
        movie_info = movie.details(random_movie_id)
        if movie_info:
            data = {
            'title': movie_info['original_title'],
            'release_date': movie_info['release_date'],
            'budget': movie_info['budget'],
            'revenue': movie_info['revenue']
            }
            movie_data.append(data)
            num_mov+=1
            print(data)
    except TMDbException as e:
        print(f"Skipped {random_movie_id}; {e}")
df = pd.DataFrame(movie_data)
excel_file_name = 'random_movies.xlsx'
df.to_excel(excel_file_name,index=False)
# Out:
# {'title': 'Evolution', 'release_date': '2001-06-08', 'budget': 80000000, 'revenue': 98376292}
# {'title': 'Nada', 'release_date': '1974-02-06', 'budget': 0, 'revenue': 0}
# {'title': 'Vier Minuten', 'release_date': '2006-06-23', 'budget': 0, 'revenue': 0}
# Skipped 3130; The resource you requested could not be found.
# Skipped 8742; The resource you requested could not be found.
# {'title': 'All Stars', 'release_date': '1997-05-01', 'budget': 0, 'revenue': 0}
# Skipped 7969; The resource you requested could not be found.
# {'title': 'The Bridge on the River Kwai', 'release_date': '1957-10-11', 'budget': 3000000, 'revenue': 44908000}
# {'title': "Mary Shelley's Frankenstein", 'release_date': '1994-11-04', 'budget': 45000000, 'revenue': 112006296}
# {'title': 'The Lady from Shanghai', 'release_date': '1947-12-24', 'budget': 2300000, 'revenue': 1564609}
# {'title': 'Mighty Joe Young', 'release_date': '1998-12-25', 'budget': 90000000, 'revenue': 0}
# Skipped 3674; The resource you requested could not be found.
# {'title': 'Embrassez qui vous voudrez', 'release_date': '2002-03-04', 'budget': 0, 'revenue': 8738101}
# Skipped 4126; The resource you requested could not be found.
# Skipped 2315; The resource you requested could not be found.
# {'title': 'Die Weibchen', 'release_date': '1970-12-22', 'budget': 0, 'revenue': 0}
# Skipped 4303; The resource you requested could not be found.
# {'title': 'Brothers', 'release_date': '2009-12-02', 'budget': 26000000, 'revenue': 43474578}
# {'title': 'Das Testament des Cornelius Gulden', 'release_date': '1932-11-03', 'budget': 0, 'revenue': 0}
# {'title': 'Christine', 'release_date': '1983-05-11', 'budget': 9700000, 'revenue': 21200000}
# Skipped 7108; The resource you requested could not be found.
# {'title': 'Les Misérables', 'release_date': '1982-10-20', 'budget': 0, 'revenue': 0}
# Skipped 4795; The resource you requested could not be found.
# Skipped 6098; The resource you requested could not be found.
# {'title': 'Twelve Monkeys', 'release_date': '1995-12-29', 'budget': 29000000, 'revenue': 168841459}
# {'title': 'Frankenstein & the Werewolf Reborn!', 'release_date': '2005-11-01', 'budget': 0, 'revenue': 0}
# {'title': 'Das wilde Leben', 'release_date': '2007-02-01', 'budget': 0, 'revenue': 957744}
# Skipped 7693; The resource you requested could not be found.
# {'title': 'Doctor Dolittle', 'release_date': '1998-06-26', 'budget': 71000000, 'revenue': 294456605}
# Skipped 8257; The resource you requested could not be found.
# {'title': 'Duck Soup', 'release_date': '1933-11-12', 'budget': 0, 'revenue': 0}
# {'title': '싸이보그지만 괜찮아', 'release_date': '2006-12-07', 'budget': 0, 'revenue': 4354510}
# {'title': '36 Fillette', 'release_date': '1988-03-03', 'budget': 0, 'revenue': 0}
# Skipped 2827; The resource you requested could not be found.
# {'title': 'Letter from an Unknown Woman', 'release_date': '1948-04-28', 'budget': 0, 'revenue': 0}
# Skipped 4692; The resource you requested could not be found.
# {'title': 'The Piano Player', 'release_date': '2002-10-06', 'budget': 10000000, 'revenue': 0}
# Skipped 7570; The resource you requested could not be found.
# Skipped 3975; The resource you requested could not be found.
# Skipped 7725; The resource you requested could not be found.
# {'title': 'Pathfinder', 'release_date': '2007-01-11', 'budget': 45000000, 'revenue': 30822861}
# {'title': 'Der rote Elvis', 'release_date': '2007-02-13', 'budget': 0, 'revenue': 0}
# {'title': 'Days of Thunder', 'release_date': '1990-06-27', 'budget': 60000000, 'revenue': 157920733}
# {'title': 'Murder in Three Acts', 'release_date': '1986-10-01', 'budget': 0, 'revenue': 0}
# Skipped 2881; The resource you requested could not be found.
# Skipped 8399; The resource you requested could not be found.
# Skipped 2372; The resource you requested could not be found.
# {'title': '활', 'release_date': '2005-05-12', 'budget': 950000, 'revenue': 2032404}
# {'title': 'Dan in Real Life', 'release_date': '2007-10-26', 'budget': 25000000, 'revenue': 68474305}
# Skipped 5361; The resource you requested could not be found.
# Skipped 7358; The resource you requested could not be found.
# Skipped 6796; The resource you requested could not be found.
# {'title': 'Scrooged', 'release_date': '1988-11-22', 'budget': 32000000, 'revenue': 60328558}
# Skipped 3996; The resource you requested could not be found.
# {'title': 'Minority Report', 'release_date': '2002-06-20', 'budget': 102000000, 'revenue': 358372926}
# {'title': 'Dust Devil', 'release_date': '1992-07-11', 'budget': 8000000, 'revenue': 0}
# {'title': 'Big Fish', 'release_date': '2003-12-25', 'budget': 70000000, 'revenue': 123218424}
# {'title': 'Unterwegs', 'release_date': '2004-02-10', 'budget': 0, 'revenue': 0}
# {'title': 'Duel', 'release_date': '1971-11-13', 'budget': 450000, 'revenue': 0}
# {'title': 'Final Destination', 'release_date': '2000-03-17', 'budget': 23000000, 'revenue': 112880294}
# Skipped 5254; The resource you requested could not be found.
# Skipped 6063; The resource you requested could not be found.
# {'title': 'High Noon', 'release_date': '1952-06-09', 'budget': 730000, 'revenue': 8000000}
# {'title': 'Lucy', 'release_date': '2006-02-14', 'budget': 0, 'revenue': 0}
# {'title': 'Zabriskie Point', 'release_date': '1970-03-26', 'budget': 7000000, 'revenue': 1000000}
# {'title': 'Run, Simon, Run', 'release_date': '1970-12-01', 'budget': 0, 'revenue': 0}
# Skipped 5381; The resource you requested could not be found.
# Skipped 3187; The resource you requested could not be found.
# {'title': 'Signale - Ein Weltraumabenteuer', 'release_date': '1970-12-17', 'budget': 0, 'revenue': 0}
# Skipped 7157; The resource you requested could not be found.
# Skipped 3737; The resource you requested could not be found.
# {'title': 'Les Demoiselles de Rochefort', 'release_date': '1967-03-08', 'budget': 0, 'revenue': 0}
# {'title': 'Con Air', 'release_date': '1997-06-05', 'budget': 75000000, 'revenue': 224012234}
# Skipped 8184; The resource you requested could not be found.
# Skipped 7534; The resource you requested could not be found.
# Skipped 2825; The resource you requested could not be found.
# {'title': 'Arthur et les Minimoys', 'release_date': '2006-12-13', 'budget': 86000000, 'revenue': 107944236}
# Skipped 1067; The resource you requested could not be found.
# Skipped 4079; The resource you requested could not be found.
# Skipped 6344; The resource you requested could not be found.
# Skipped 9018; The resource you requested could not be found.
# {'title': 'RoboCop 3', 'release_date': '1993-05-28', 'budget': 22000000, 'revenue': 10696210}
# {'title': '40 Days and 40 Nights', 'release_date': '2002-03-01', 'budget': 17000000, 'revenue': 95146283}
# Skipped 358; The resource you requested could not be found.
# {'title': 'M. Butterfly', 'release_date': '1993-09-09', 'budget': 0, 'revenue': 1499795}
# Skipped 4046; The resource you requested could not be found.
# {'title': 'The Quiet', 'release_date': '2005-09-12', 'budget': 900000, 'revenue': 381420}
# {'title': 'Erbin mit Herz', 'release_date': '2004-10-22', 'budget': 0, 'revenue': 0}
# Skipped 3369; The resource you requested could not be found.
# Skipped 8335; The resource you requested could not be found.
# {'title': 'The Docks of New York', 'release_date': '1928-09-16', 'budget': 0, 'revenue': 0}
# {'title': 'The American President', 'release_date': '1995-11-17', 'budget': 62000000, 'revenue': 107879496}
# {'title': 'Martin et Léa', 'release_date': '1979-01-31', 'budget': 0, 'revenue': 0}
# {'title': 'Gli specialisti', 'release_date': '1969-11-25', 'budget': 0, 'revenue': 0}
# Skipped 1100; The resource you requested could not be found.
# {'title': 'Spanglish', 'release_date': '2004-12-17', 'budget': 80000000, 'revenue': 55041367}
# Skipped 7855; The resource you requested could not be found.
# {'title': '...und deine Liebe auch', 'release_date': '1962-09-27', 'budget': 0, 'revenue': 0}
# Skipped 3279; The resource you requested could not be found.
# {'title': 'Edge of Seventeen', 'release_date': '1998-05-14', 'budget': 1500000, 'revenue': 870751}
# Skipped 2426; The resource you requested could not be found.
# Skipped 2917; The resource you requested could not be found.
# {'title': 'ביקור התזמורת', 'release_date': '2007-05-19', 'budget': 0, 'revenue': 0}
# Skipped 1158; The resource you requested could not be found.
# {'title': 'El baño del Papa', 'release_date': '2007-05-21', 'budget': 0, 'revenue': 0}
# Skipped 7254; The resource you requested could not be found.
# Skipped 6837; The resource you requested could not be found.
# Skipped 6993; The resource you requested could not be found.
# Skipped 5414; The resource you requested could not be found.
# {'title': 'Die Geierwally', 'release_date': '2005-01-07', 'budget': 0, 'revenue': 0}
# {'title': 'Crocodile Dundee II', 'release_date': '1988-05-19', 'budget': 14000000, 'revenue': 239606210}
# {'title': 'Herr Ober!', 'release_date': '1992-01-31', 'budget': 0, 'revenue': 0}
# {'title': 'Sublime', 'release_date': '2007-06-15', 'budget': 0, 'revenue': 0}
# {'title': 'La Casa 4', 'release_date': '1988-12-01', 'budget': 0, 'revenue': 0}
# Skipped 8139; The resource you requested could not be found.
# {'title': "Where's Willie?", 'release_date': '1978-04-12', 'budget': 0, 'revenue': 0}
# Skipped 6518; The resource you requested could not be found.
# {'title': 'Der Schandfleck', 'release_date': '1956-12-14', 'budget': 0, 'revenue': 0}
# {'title': 'Be Cool', 'release_date': '2005-03-04', 'budget': 53000000, 'revenue': 95226116}
# {'title': 'The Man Who Haunted Himself', 'release_date': '1970-09-17', 'budget': 525497, 'revenue': 0}
# {'title': 'Goodbye Bafana', 'release_date': '2007-02-11', 'budget': 30000000, 'revenue': 0}
# Skipped 6100; The resource you requested could not be found.
# {'title': 'Diva', 'release_date': '1981-03-11', 'budget': 0, 'revenue': 0}
# {'title': "Her Sister's Keeper", 'release_date': '2006-11-26', 'budget': 0, 'revenue': 0}
# {'title': 'Trade', 'release_date': '2007-01-23', 'budget': 12000000, 'revenue': 0}
# {'title': 'The Final Cut', 'release_date': '1995-11-05', 'budget': 0, 'revenue': 551281}
# {'title': 'Land of Plenty', 'release_date': '2004-09-10', 'budget': 0, 'revenue': 0}
# {'title': 'Wie die Karnickel', 'release_date': '2002-09-12', 'budget': 0, 'revenue': 0}
# Skipped 1071; The resource you requested could not be found.
# Skipped 2482; The resource you requested could not be found.
# Skipped 4066; The resource you requested could not be found.
# Skipped 5877; The resource you requested could not be found.
# Skipped 3284; The resource you requested could not be found.
# {'title': 'Wild Orchid II: Two Shades of Blue', 'release_date': '1991-10-31', 'budget': 0, 'revenue': 573904}
# {'title': 'Scary Movie 4', 'release_date': '2006-04-12', 'budget': 45000000, 'revenue': 178262620}
# {'title': 'Rain Man', 'release_date': '1988-12-12', 'budget': 25000000, 'revenue': 354825435}
# {'title': 'سكر بنات', 'release_date': '2007-08-09', 'budget': 0, 'revenue': 0}
# Skipped 7126; The resource you requested could not be found.
# Skipped 5348; The resource you requested could not be found.
# Skipped 5496; The resource you requested could not be found.
# Skipped 3005; The resource you requested could not be found.
# {'title': 'سكر بنات', 'release_date': '2007-08-09', 'budget': 0, 'revenue': 0}
# Skipped 7252; The resource you requested could not be found.
# Skipped 5091; The resource you requested could not be found.
# {'title': 'The Wicker Man', 'release_date': '2006-08-31', 'budget': 40000000, 'revenue': 38805380}
# {'title': 'Fadern', 'release_date': '1969-10-10', 'budget': 0, 'revenue': 0}
# {'title': 'American Pie', 'release_date': '1999-07-09', 'budget': 11000000, 'revenue': 235483004}
# {'title': 'John Tucker Must Die', 'release_date': '2006-07-27', 'budget': 18000000, 'revenue': 68844775}
# Skipped 3919; The resource you requested could not be found.
# {'title': "Histoire d'O", 'release_date': '1975-08-27', 'budget': 0, 'revenue': 0}
# Skipped 4770; The resource you requested could not be found.
# {'title': 'The Wild', 'release_date': '2006-04-06', 'budget': 80000000, 'revenue': 102338515}
# Skipped 8725; The resource you requested could not be found.
# {'title': 'Die Fälscher', 'release_date': '2007-03-22', 'budget': 0, 'revenue': 0}
# {'title': 'Arlington Road', 'release_date': '1999-03-19', 'budget': 31000000, 'revenue': 41067311}
# Skipped 3706; The resource you requested could not be found.
# Skipped 8787; The resource you requested could not be found.
# Skipped 7426; The resource you requested could not be found.
# {'title': 'The Day of the Jackal', 'release_date': '1973-05-15', 'budget': 0, 'revenue': 16056255}
# Skipped 3390; The resource you requested could not be found.
# Skipped 6799; The resource you requested could not be found.
# Skipped 5882; The resource you requested could not be found.
# Skipped 5412; The resource you requested could not be found.
# Skipped 9172; The resource you requested could not be found.
# Skipped 8911; The resource you requested could not be found.
# Skipped 7709; The resource you requested could not be found.
# {'title': 'Hollywoodland', 'release_date': '2006-08-31', 'budget': 0, 'revenue': 16803753}
# Skipped 2519; The resource you requested could not be found.
# {'title': 'Flatliners', 'release_date': '1990-08-10', 'budget': 26000000, 'revenue': 61489265}
# Skipped 6090; The resource you requested could not be found.
# Skipped 7238; The resource you requested could not be found.
# {'title': 'Saw', 'release_date': '2004-10-01', 'budget': 1200000, 'revenue': 103911669}
# {'title': 'Show de Bola', 'release_date': '2008-01-30', 'budget': 0, 'revenue': 123045}
# Skipped 4524; The resource you requested could not be found.
# Skipped 1043; The resource you requested could not be found.
# Skipped 9135; The resource you requested could not be found.
# Skipped 6539; The resource you requested could not be found.
# Skipped 2870; The resource you requested could not be found.
# Skipped 5379; The resource you requested could not be found.
# {'title': 'Local Color', 'release_date': '2006-09-19', 'budget': 3250000, 'revenue': 32788}
# {'title': 'King of New York', 'release_date': '1990-07-18', 'budget': 0, 'revenue': 0}
# Skipped 3992; The resource you requested could not be found.
# {'title': 'Wizards of the Lost Kingdom II', 'release_date': '1989-03-01', 'budget': 0, 'revenue': 0}
# {'title': 'Taxi Driver', 'release_date': '1976-02-09', 'budget': 1900000, 'revenue': 28600000}
# Skipped 7028; The resource you requested could not be found.
# Skipped 3278; The resource you requested could not be found.
# {'title': 'The Godfather Part III', 'release_date': '1990-12-25', 'budget': 54000000, 'revenue': 136766062}
# {'title': 'Kommissar X - Drei goldene Schlangen', 'release_date': '1969-04-18', 'budget': 0, 'revenue': 0}
# {'title': 'Der Golem, wie er in die Welt kam', 'release_date': '1920-10-28', 'budget': 0, 'revenue': 0}
# {'title': 'Los sin nombre', 'release_date': '1999-10-08', 'budget': 0, 'revenue': 1069154}
