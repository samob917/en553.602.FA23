# %%
import pandas as pd
import ast

main_details = pd.read_csv("../../3. Data Preparation/3.3 Construct Data/merged_data_with_revenues_with_release_years.csv")

for year in range(2013,2024):
    df_bom = pd.read_excel(f"../2.1 Collect Initial Data/Box Office Mojo Domestic Box Office by Year/Domestic Box Office By Year/{year}_top_box_office.xlsx")
    missing_count = 0
    for title in df_bom["Title"]:
        if title not in main_details['Title_y'].values:
            print(title)
            missing_count += 1
# Out:
# Monsters University
# Jurassic Park2013 Re-release
# Instructions Not Included
# Walking with Dinosaurs 3D
# Texas Chainsaw
# Scary Movie V
# Quartet
# Dhoom 3
# The Grandmaster
# Pulling Strings
# The Wizard of Oz2013 3D/IMAX Release
# Chennai Express
# The Company You Keep
# Much Ado About Nothing
# Yeh Jawaani Hai Deewani
# Metallica Through the Never
# Emperor
# Stand Up Guys
# Top Gun2013 3D Release
# The Great Beauty
# RamLeela
# The Sapphires
# The Gatekeepers
# No
# Renoir
# Blue Is the Warmest Colour
# Krrish 3
# The Oscar Nominated Short Films 2013: Live Action
# The Iceman
# Fill the Void
# Girl Rising
# The Attack
# Unfinished Song
# Bhaag Milkha Bhaag
# Love Is All You Need
# Stories We Tell
# Race 2
# Kon-Tiki
# Girl Most Likely
# I'm So Excited!
# Wadjda
# PK
# Meet the Mormons
# Cesar Chavez2014 Re-release
# The Wind Rises
# Snowpiercer
# The Lunchbox2013 Re-release
# Ida
# Ghostbusters30th Anniversary Release
# The Fluffy Movie: Unity Through Laughter
# ...
