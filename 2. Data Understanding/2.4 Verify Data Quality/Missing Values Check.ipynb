# %%
import pandas as pd
import ast

df_details = pd.read_csv("../../3. Data Preparation/3.3 Construct Data/merged_data_with_revenues.csv")
print(type(df_details['Release Date'][1]))

for year in range(2013,2024):
    df_bom = pd.read_excel(f"../2.1 Collect Initial Data/Box Office Mojo Domestic Box Office by Year/Domestic Box Office By Year/{year}_top_box_office.xlsx")
    print(df_bom)
# Out:
# <class 'str'>
#                                Title       Revenue
# 0                         Iron Man 3  $409,013,994
# 1    The Hunger Games: Catching Fire  $395,526,705
# 2                    Despicable Me 2  $367,793,270
# 3                       Man of Steel  $291,045,518
# 4                Monsters University  $268,492,764
# ..                               ...           ...
# 195                         The East    $2,301,839
# 196                           Renoir    $2,293,798
# 197             The Christmas Candle    $2,252,400
# 198                         Krrish 3    $2,191,534
# 199                           Oldboy    $2,190,524
#
# [200 rows x 2 columns]
#                                      Title       Revenue
# 0                  Guardians of the Galaxy  $332,934,626
# 1    The Hunger Games: Mockingjay - Part 1  $313,282,914
# 2      Captain America: The Winter Soldier  $259,766,572
# 3                           The Lego Movie  $257,760,692
# ...
